# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import turtle
F = np.linspace(0,10,11)
#Radius of Sphere
R = 0.06
# Poisson Ratio of material (this is assumed i do not have real value of material)
v1 = 0.33
v2 = 0.33
#Elestic Moduli
E1 = 2200000000
E2 = E1


E = 0.5 *((1-v1)/E1)+((1-v2)/E2)
print (E)
#
E = 1/E
print(E)
#Radius of contact Area
a = (3/2 * (R*F)/E)**(1/3)
print (a)
plt.figure(1, dpi=150)
plt.plot(a,F)
plt.xlabel('Contact Area Radius [m]')
plt.ylabel('Force [N]')
plt.title('Hertzian Contact ')
import matplotlib.patches as mpatches

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.collections
print (a)






# x = np.linspace(-1,1,1000)
# r = a[2]
# y = np.sqrt( r * np.ones(1000) - x**2)

# plt.plot (x,y)
# plt.plot(x,-y)


plt.figure(1)

fig, ax = plt.subplots(dpi = 90) # note we must use plt.subplots, not plt.subplot
for i in a :
    circle1 = plt.Circle((0, 0), i , fc = 'none' ,ec = 'black')
    ax.add_artist(circle1)
ax.set_xlim([-0.00075,0.00075])
ax.set_ylim([-0.00075,0.00075])
ax.set_xlabel('X [m]')
ax.set_ylabel('y[m]')
ax.set_title('Contact area at different forces ')

plt.show()
# Out:
# 4.5681818181818175e-10
# 2189054726.36816
# [ 0.          0.00034514  0.00043485  0.00049778  0.00054788  0.00059018
#   0.00062716  0.00066023  0.00069028  0.00071792  0.00074358]
# [ 0.          0.00034514  0.00043485  0.00049778  0.00054788  0.00059018
#   0.00062716  0.00066023  0.00069028  0.00071792  0.00074358]
